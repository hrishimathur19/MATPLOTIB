# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# TYPES OF PLOTS

# %%
x = np.linspace(0,5,11)
y = np.linspace(2,8,11)

# %%
plt.scatter(x,y)

# %%
#histogram

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([12., 11.,  5., 11.,  7., 10., 12.,  6., 12., 14.]),
#  array([  3. , 101.9, 200.8, 299.7, 398.6, 497.5, 596.4, 695.3, 794.2,
#         893.1, 992. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dc2c6160c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dc2c620410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dc2c615d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dc2c620950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dc2c620c50>],
#  'means': []}
