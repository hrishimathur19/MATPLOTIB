# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# suboplot

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr"]
sales = [100, 150, 120, 200]
plt.plot(months,sales)
