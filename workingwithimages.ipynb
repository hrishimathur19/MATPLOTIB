# %% [markdown]
# WORKING WITH IMAGES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("images.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
crop = img[50:100, 100:300]
plt.imshow(crop)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(174.5), np.float64(49.5), np.float64(-0.5))

# %%
 #optional designing

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(x,y,color="pink")
#
# NameError: name 'x' is not defined
